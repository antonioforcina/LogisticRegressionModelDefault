# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#INSTALL-PACKAGES" data-toc-modified-id="INSTALL-PACKAGES-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>INSTALL PACKAGES</a></span></li><li><span><a href="#LOADING-DATA" data-toc-modified-id="LOADING-DATA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>LOADING DATA</a></span></li><li><span><a href="#EXPLORATORY-DATA-ANALYSIS" data-toc-modified-id="EXPLORATORY-DATA-ANALYSIS-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EXPLORATORY DATA ANALYSIS</a></span></li><li><span><a href="#CORRELATION-ANALYSIS" data-toc-modified-id="CORRELATION-ANALYSIS-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>CORRELATION ANALYSIS</a></span></li><li><span><a href="#REMOVE-OUTLIERS" data-toc-modified-id="REMOVE-OUTLIERS-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>REMOVE OUTLIERS</a></span></li><li><span><a href="#Analyzing-income" data-toc-modified-id="Analyzing-income-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Analyzing income</a></span></li><li><span><a href="#Analizing-car-value" data-toc-modified-id="Analizing-car-value-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Analizing car value</a></span></li><li><span><a href="#Analyzing-OTH-DEBT" data-toc-modified-id="Analyzing-OTH-DEBT-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Analyzing OTH DEBT</a></span></li><li><span><a href="#ANALYZING-CREDDEBT" data-toc-modified-id="ANALYZING-CREDDEBT-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>ANALYZING CREDDEBT</a></span></li><li><span><a href="#VARIABLE-SELECTION-DIFFERENT-MODELS" data-toc-modified-id="VARIABLE-SELECTION-DIFFERENT-MODELS-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>VARIABLE SELECTION DIFFERENT MODELS</a></span></li><li><span><a href="#Best-subset-procedure" data-toc-modified-id="Best-subset-procedure-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Best subset procedure</a></span></li><li><span><a href="#MORE-ABOUT-SELECTING-VARIABLES" data-toc-modified-id="MORE-ABOUT-SELECTING-VARIABLES-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>MORE ABOUT SELECTING VARIABLES</a></span></li><li><span><a href="#BEST-SUBSET-REGRESSION" data-toc-modified-id="BEST-SUBSET-REGRESSION-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>BEST SUBSET REGRESSION</a></span></li><li><span><a href="#Stepwise-forward-regression" data-toc-modified-id="Stepwise-forward-regression-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Stepwise forward regression</a></span></li><li><span><a href="#Stepwise-Backward-Regression" data-toc-modified-id="Stepwise-Backward-Regression-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Stepwise Backward Regression</a></span></li><li><span><a href="#Stepwise-Regression" data-toc-modified-id="Stepwise-Regression-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Stepwise Regression</a></span></li><li><span><a href="#CHECKING-NORMAL-DISTRIBUTION-VARIABLES" data-toc-modified-id="CHECKING-NORMAL-DISTRIBUTION-VARIABLES-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>CHECKING NORMAL DISTRIBUTION VARIABLES</a></span></li><li><span><a href="#Income" data-toc-modified-id="Income-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Income</a></span></li><li><span><a href="#Othdebt" data-toc-modified-id="Othdebt-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Othdebt</a></span></li><li><span><a href="#Carvalue" data-toc-modified-id="Carvalue-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>Carvalue</a></span></li><li><span><a href="#Creddebt" data-toc-modified-id="Creddebt-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>Creddebt</a></span></li><li><span><a href="#yrsed" data-toc-modified-id="yrsed-22"><span class="toc-item-num">22&nbsp;&nbsp;</span>yrsed</a></span></li><li><span><a href="#BUILD-MODEL-STARTING-FROM-ALL-VARIABLES" data-toc-modified-id="BUILD-MODEL-STARTING-FROM-ALL-VARIABLES-23"><span class="toc-item-num">23&nbsp;&nbsp;</span>BUILD MODEL STARTING FROM ALL VARIABLES</a></span></li><li><span><a href="#Simple-Linear-Model" data-toc-modified-id="Simple-Linear-Model-24"><span class="toc-item-num">24&nbsp;&nbsp;</span>Simple Linear Model</a></span></li><li><span><a href="#SYNTHETIC-MODEL" data-toc-modified-id="SYNTHETIC-MODEL-25"><span class="toc-item-num">25&nbsp;&nbsp;</span>SYNTHETIC MODEL</a></span></li><li><span><a href="#log-linear-model" data-toc-modified-id="log-linear-model-26"><span class="toc-item-num">26&nbsp;&nbsp;</span>log linear model</a></span></li><li><span><a href="#log-log-model" data-toc-modified-id="log-log-model-27"><span class="toc-item-num">27&nbsp;&nbsp;</span>log log model</a></span></li><li><span><a href="#CHECK-MODELS" data-toc-modified-id="CHECK-MODELS-28"><span class="toc-item-num">28&nbsp;&nbsp;</span>CHECK MODELS</a></span></li><li><span><a href="#TEST-OF-NORMALITY-OF-RESIDUALS" data-toc-modified-id="TEST-OF-NORMALITY-OF-RESIDUALS-29"><span class="toc-item-num">29&nbsp;&nbsp;</span>TEST OF NORMALITY OF RESIDUALS</a></span></li><li><span><a href="#Simple-Linear-Model" data-toc-modified-id="Simple-Linear-Model-30"><span class="toc-item-num">30&nbsp;&nbsp;</span>Simple Linear Model</a></span></li><li><span><a href="#Synthetic-Model" data-toc-modified-id="Synthetic-Model-31"><span class="toc-item-num">31&nbsp;&nbsp;</span>Synthetic Model</a></span></li><li><span><a href="#log-linear-Model" data-toc-modified-id="log-linear-Model-32"><span class="toc-item-num">32&nbsp;&nbsp;</span>log linear Model</a></span></li><li><span><a href="#loglogm" data-toc-modified-id="loglogm-33"><span class="toc-item-num">33&nbsp;&nbsp;</span>loglogm</a></span></li><li><span><a href="#Test-of-Homoscedasticity" data-toc-modified-id="Test-of-Homoscedasticity-34"><span class="toc-item-num">34&nbsp;&nbsp;</span>Test of Homoscedasticity</a></span></li></ul></div>

# %% [markdown]
# # INSTALL PACKAGES

# %%
install.packages('car')
library(car)
install.packages('caret')
library(caret)
install.packages('olsrr')
library(olsrr)
# Out:
# Installing package into 'C:/Users/anton/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'car' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\anton\AppData\Local\Temp\RtmpyyNjMC\downloaded_packages
# Warning message:
# "package 'car' was built under R version 4.1.3"
# Loading required package: carData
#
# Warning message:
# "package 'carData' was built under R version 4.1.3"
# Installing package into 'C:/Users/anton/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'caret' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\anton\AppData\Local\Temp\RtmpyyNjMC\downloaded_packages
# Warning message:
# "package 'caret' was built under R version 4.1.3"
# Loading required package: ggplot2
#
# Loading required package: lattice
#
# Installing package into 'C:/Users/anton/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# ...

# %% [markdown]
# # LOADING DATA

# %%
IncomeData <- read.csv('IncomeData.csv')

# %%
nrow(IncomeData)
# Out:
# [1] 4508

# %%
names(IncomeData)[names(IncomeData) == 'ï..age'] <- 'age'

# %%
head(IncomeData)
# Out:
#   age yrsed edcat yrsempl income creddebt othdebt  default jobsat homeown
# 1 45  6     1      4      17     0.371518 1.294482 0       4      1
# 2 67  6     1     15      12     0.375552 0.392448 0       3      1
# 3 68  6     1      7       9     0.200970 0.789030 0       5      0
# 4 75  6     1     35      16     0.314096 0.757904 0       4      0
# 5 38  7     1      8      37     0.143190 0.411810 0       3      0
# 6 49  7     1      4      21     0.262143 1.270857 0       1      1
#   address cars carvalue
# 1 22      1     9.1
# 2 28      1     5.9
# 3 21      1     5.8
# 4 11      1     5.8
# 5 11      1    22.1
# 6 14      1    10.8

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
summary(IncomeData)
# Out:
#       age            yrsed           edcat          yrsempl
#  Min.   :18.00   Min.   : 6.00   Min.   :1.000   Min.   : 0.000
#  1st Qu.:32.00   1st Qu.:12.00   1st Qu.:2.000   1st Qu.: 2.000
#  Median :46.00   Median :14.00   Median :2.000   Median : 7.000
#  Mean   :46.93   Mean   :14.53   Mean   :2.667   Mean   : 9.719
#  3rd Qu.:62.00   3rd Qu.:17.00   3rd Qu.:4.000   3rd Qu.:15.000
#  Max.   :79.00   Max.   :23.00   Max.   :5.000   Max.   :52.000
#      income           creddebt           othdebt            default
#  Min.   :   9.00   Min.   :  0.0000   Min.   :  0.0000   Min.   :0.0000
#  1st Qu.:  24.00   1st Qu.:  0.3879   1st Qu.:  0.9828   1st Qu.:0.0000
#  Median :  38.00   Median :  0.9318   Median :  2.0816   Median :0.0000
#  Mean   :  55.41   Mean   :  1.8979   Mean   :  3.6915   Mean   :0.2389
#  3rd Qu.:  68.00   3rd Qu.:  2.0765   3rd Qu.:  4.4351   3rd Qu.:0.0000
#  Max.   :1073.00   Max.   :109.0726   Max.   :141.4591   Max.   :1.0000
# ...

# %% [markdown]
# # CORRELATION ANALYSIS

# %%
install.packages('ggcorrplot')
library(ggcorrplot)
# Out:
# Installing package into 'C:/Users/anton/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'ggcorrplot' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\anton\AppData\Local\Temp\RtmpyyNjMC\downloaded_packages
# Warning message:
# "package 'ggcorrplot' was built under R version 4.1.3"

# %%
IncomeDataCorr <- cor(IncomeData, use = 'pairwise.complete.obs')
ggcorrplot(IncomeDataCorr, title="NoOutliers1", lab = TRUE)
# Out:
# plot without title

# %%
#Removing correlated variables to avoid multicollinearity (yrsempl, edcat)

# %%
IncomeData1 = subset(IncomeData, select = -c(age ,edcat) )
head(IncomeData1)
# Out:
#   yrsed yrsempl income creddebt othdebt  default jobsat homeown address cars
# 1 6      4      17     0.371518 1.294482 0       4      1       22      1
# 2 6     15      12     0.375552 0.392448 0       3      1       28      1
# 3 6      7       9     0.200970 0.789030 0       5      0       21      1
# 4 6     35      16     0.314096 0.757904 0       4      0       11      1
# 5 7      8      37     0.143190 0.411810 0       3      0       11      1
# 6 7      4      21     0.262143 1.270857 0       1      1       14      1
#   carvalue
# 1  9.1
# 2  5.9
# 3  5.8
# 4  5.8
# 5 22.1
# 6 10.8

# %% [markdown]
# # REMOVE OUTLIERS

# %%
boxplot(IncomeData1, main="Income Data Boxplot")
# Out:
# Plot with title "Income Data Boxplot"

# %% [markdown]
# # Analyzing income

# %%
boxplot(IncomeData1$income, main="Income")
# Out:
# Plot with title "Income"

# %%
Q1 <- quantile(IncomeData1$income, .25)
Q3 <- quantile(IncomeData1$income, .75)
IQR <- IQR(IncomeData1$income)
IncomeData2 <- subset(IncomeData1, IncomeData1$income > (Q1 - 1.5*IQR) & IncomeData1$income < (Q3 + 1.5*IQR))

# %%
nrow(IncomeData2)
# Out:
# [1] 4200

# %%
boxplot(IncomeData2$income)
# Out:
# plot without title

# %%
#outliers to be deleted
#ToBeDeleted=subset(IncomeData1, income>150)
#nrow(ToBeDeleted)

# %%
#IncomeData2=subset(IncomeData1, income<=150)

# %%
#nrow(IncomeData2)

# %%
#boxplot(IncomeData2$income)

# %% [markdown]
# # Analizing car value

# %%
boxplot(IncomeData2$carvalue, main="Car value")
# Out:
# Plot with title "Car value"

# %%
Q1 <- quantile(IncomeData2$carvalue, .25)
Q3 <- quantile(IncomeData2$carvalue, .75)
IQR <- IQR(IncomeData2$carvalue)
IncomeData3 <- subset(IncomeData2, IncomeData2$carvalue > (Q1 - 1.5*IQR) & IncomeData2$carvalue < (Q3 + 1.5*IQR))

# %%
nrow(IncomeData3)
# Out:
# [1] 4072

# %%
boxplot(IncomeData3$carvalue)
# Out:
# plot without title

# %%
#carvalue=subset(IncomeData2, carvalue>=75)
#nrow(carvalue)

# %%
#IncomeData3=subset(IncomeData2, carvalue<=75)
#nrow(IncomeData3)

# %%
boxplot(IncomeData3)
# Out:
# plot without title

# %% [markdown]
# # Analyzing OTH DEBT

# %%
boxplot(IncomeData3$othdebt, main="Other Debts")
# Out:
# Plot with title "Other Debts"

# %%
Q1 <- quantile(IncomeData2$othdebt, .25)
Q3 <- quantile(IncomeData2$othdebt, .75)
IQR <- IQR(IncomeData2$othdebt)
IncomeData3 <- subset(IncomeData2, IncomeData2$othdebt > (Q1 - 1.5*IQR) & IncomeData2$othdebt < (Q3 + 1.5*IQR))

# %%
nrow(IncomeData3)
# Out:
# [1] 3922

# %%
boxplot(IncomeData3$othdebt)
# Out:
# plot without title

# %% [markdown]
# # ANALYZING CREDDEBT

# %%
boxplot(IncomeData3$creddebt, main="Credit Debts")
# Out:
# Plot with title "Credit Debts"

# %%
Q1 <- quantile(IncomeData2$creddebt, .25)
Q3 <- quantile(IncomeData2$creddebt, .75)
IQR <- IQR(IncomeData2$creddebt)
IncomeData3 <- subset(IncomeData3, IncomeData3$creddebt > (Q1 - 1.5*IQR) & IncomeData3$creddebt < (Q3 + 1.5*IQR))

# %%
nrow(IncomeData3)
# Out:
# [1] 3700

# %%
boxplot(IncomeData3$othdebt)
# Out:
# plot without title

# %%
boxplot(IncomeData3, main="Boxplot of dataset")
# Out:
# Plot with title "Boxplot of dataset"

# %% [markdown]
# # VARIABLE SELECTION DIFFERENT MODELS

# %% [markdown]
# # Best subset procedure

# %%
#LEAPS FUNCTION

# %%
# All Subsets Regression
#packages
install.packages("leaps")
library(leaps)
install.packages("car")
library(car)
# Out:
# Installing package into 'C:/Users/anton/Documents/R/win-library/4.1'
# (as 'lib' is unspecified)
# package 'leaps' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\anton\AppData\Local\Temp\RtmpyyNjMC\downloaded_packages
# Warning message:
# "package 'leaps' was built under R version 4.1.3"
# Warning message:
# "package 'car' is in use and will not be installed"

# %%
BestFit=regsubsets(income~ yrsed+yrsempl+creddebt+othdebt+default+jobsat+homeown+address+cars+carvalue, data=IncomeData3, nbest=2)

# %%
#par(mfrow=c(1,1))
#subsets(BestFit, statistic="adjr2")

# %%
plot(BestFit, scale="adjr2")
# Out:
# plot without title

# %%
#we should take the less variables as possible

# %% [markdown]
# # MORE ABOUT SELECTING VARIABLES

# %%
#https://cran.r-project.org/web/packages/olsrr/vignettes/variable_selection.html

# %%
install.packages("olsrr")
library(olsrr)
# Out:
# Warning message:
# "package 'olsrr' is in use and will not be installed"

# %% [markdown]
# # BEST SUBSET REGRESSION

# %%
model <- lm(income ~ ., data = IncomeData3)
ols_step_best_subset(model)
# Out:
#      mindex n
# 10    1      1
# 40    2      2
# 125   3      3
# 320   4      4
# 446   5      5
# 642   6      6
# 857   7      7
# 973   8      8
# 1015  9      9
# 1023 10     10
#      predictors
# 10   carvalue
# 40   othdebt carvalue
# 125  creddebt othdebt carvalue
# 320  creddebt othdebt default carvalue
# 446  yrsed creddebt othdebt default carvalue
# 642  yrsed yrsempl creddebt othdebt default carvalue
# 857  yrsed yrsempl creddebt othdebt default cars carvalue
# 973  yrsed yrsempl creddebt othdebt default jobsat cars carvalue
# 1015 yrsed yrsempl creddebt othdebt default jobsat homeown cars carvalue
# 1023 yrsed yrsempl creddebt othdebt default jobsat homeown address cars carvalue
#      rsquare   adjr      predrsq   cp         aic      sbic     sbc
# 10   0.8783899 0.8783570 0.8781387 240.036925 26494.07 15993.68 26512.72
# 40   0.8833642 0.8833011 0.8830144  81.038062 26341.54 15841.28 26366.41
# 125  0.8842854 0.8841914 0.8838466  53.224027 26314.21 15813.96 26345.29
# ...

# %%
k <- ols_step_best_subset(model)
plot(k)
# Out:
# [[1]]
# NULL
#
# [[2]]
# NULL
# plot without title
# plot without title

# %% [markdown]
# # Stepwise forward regression

# %%
model <- lm(income ~ ., data = IncomeData3)
ols_step_forward_p(model)
# Out:
#                              Selection Summary
# ----------------------------------------------------------------------------
#         Variable                  Adj.
# Step    Entered     R-Square    R-Square      C(p)         AIC         RMSE
# ----------------------------------------------------------------------------
#    1    carvalue      0.8784      0.8784    240.0369    26494.0704    8.6781
#    2    othdebt       0.8834      0.8833     81.0381    26341.5440    8.4999
#    3    creddebt      0.8843      0.8842     53.2240    26314.2066    8.4674
#    4    default       0.8853      0.8852     23.1970    26284.4303    8.4323
#    5    yrsed         0.8857      0.8856     10.5034    26271.7598    8.4167
#    6    yrsempl       0.8859      0.8857      7.8874    26269.1391    8.4126
#    7    cars          0.8859      0.8857      8.2798    26269.5285    8.4119
#    8    jobsat        0.8860      0.8857      8.7611    26270.0063    8.4113
# ...

# %%
k <- ols_step_forward_p(model)
plot(k)
# Out:
# [[1]]
# NULL
#
# [[2]]
# NULL
# plot without title
# plot without title

# %%
ols_step_forward_p(model, details = TRUE)
# Out:
# Forward Selection Method
# ---------------------------
#
# Candidate Terms:
#
# 1. yrsed
# 2. yrsempl
# 3. creddebt
# 4. othdebt
# 5. default
# 6. jobsat
# 7. homeown
# 8. address
# 9. cars
# 10. carvalue
#
# We are selecting variables based on p value...
#
#
# Forward Selection: Step 1
#
# - carvalue
#
#                         Model Summary
# --------------------------------------------------------------
# R                       0.937       RMSE                8.678
# R-Squared               0.878       Coef. Var          21.937
# Adj. R-Squared          0.878       MSE                75.309
# Pred R-Squared          0.878       MAE                 5.991
# --------------------------------------------------------------
#  RMSE: Root Mean Square Error
#  MSE: Mean Square Error
#  MAE: Mean Absolute Error
#
#                                    ANOVA
# ----------------------------------------------------------------------------
#                    Sum of
# ...

# %% [markdown]
# # Stepwise Backward Regression

# %%
model1 <- lm(income ~ ., data = IncomeData3)
ols_step_backward_p(model1)
# Out:
#                            Elimination Summary
# --------------------------------------------------------------------------
#         Variable                  Adj.
# Step    Removed     R-Square    R-Square     C(p)        AIC         RMSE
# --------------------------------------------------------------------------
#    1    address        0.886      0.8857    9.3202    26270.5615    8.4108
# --------------------------------------------------------------------------

# %%
k <- ols_step_backward_p(model1)
plot(k)
# Out:
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# [[1]]
# NULL
#
# [[2]]
# NULL
# plot without title
# plot without title

# %%
ols_step_backward_p(model1, details = TRUE)
# Out:
# Backward Elimination Method
# ---------------------------
#
# Candidate Terms:
#
# 1 . yrsed
# 2 . yrsempl
# 3 . creddebt
# 4 . othdebt
# 5 . default
# 6 . jobsat
# 7 . homeown
# 8 . address
# 9 . cars
# 10 . carvalue
#
# We are eliminating variables based on p value...
#
# - address
#
# Backward Elimination: Step 1
#
#  Variable address Removed
#
#                         Model Summary
# --------------------------------------------------------------
# R                       0.941       RMSE                8.411
# R-Squared               0.886       Coef. Var          21.261
# Adj. R-Squared          0.886       MSE                70.742
# Pred R-Squared          0.885       MAE                 5.780
# --------------------------------------------------------------
#  RMSE: Root Mean Square Error
#  MSE: Mean Square Error
#  MAE: Mean Absolute Error
#
#                                    ANOVA
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# # Stepwise Regression

# %%
model2 <- lm(income ~ ., data = IncomeData3)
ols_step_both_p(model2)
# Out:
#                                Stepwise Selection Summary
# ----------------------------------------------------------------------------------------
#                      Added/                   Adj.
# Step    Variable    Removed     R-Square    R-Square      C(p)         AIC         RMSE
# ----------------------------------------------------------------------------------------
#    1    carvalue    addition       0.878       0.878    240.0370    26494.0704    8.6781
#    2    othdebt     addition       0.883       0.883     81.0380    26341.5440    8.4999
#    3    creddebt    addition       0.884       0.884     53.2240    26314.2066    8.4674
#    4    default     addition       0.885       0.885     23.1970    26284.4303    8.4323
#    5     yrsed      addition       0.886       0.886     10.5030    26271.7598    8.4167
#    6    yrsempl     addition       0.886       0.886      7.8870    26269.1391    8.4126
# ...

# %%
k <- ols_step_both_p(model2)
plot(k)
# Out:
# [[1]]
# NULL
#
# [[2]]
# NULL
# plot without title
# plot without title

# %%
ols_step_both_p(model2, details = TRUE)
# Out:
# Stepwise Selection Method
# ---------------------------
#
# Candidate Terms:
#
# 1. yrsed
# 2. yrsempl
# 3. creddebt
# 4. othdebt
# 5. default
# 6. jobsat
# 7. homeown
# 8. address
# 9. cars
# 10. carvalue
#
# We are selecting variables based on p value...
#
#
# Stepwise Selection: Step 1
#
# - carvalue added
#
#                         Model Summary
# --------------------------------------------------------------
# R                       0.937       RMSE                8.678
# R-Squared               0.878       Coef. Var          21.937
# Adj. R-Squared          0.878       MSE                75.309
# Pred R-Squared          0.878       MAE                 5.991
# --------------------------------------------------------------
#  RMSE: Root Mean Square Error
#  MSE: Mean Square Error
#  MAE: Mean Absolute Error
#
#                                    ANOVA
# ----------------------------------------------------------------------------
#                    Sum of
# ...

# %% [markdown]
# # CHECKING NORMAL DISTRIBUTION VARIABLES

# %%
#checking normality for the 6 variables income,othdebt+carvalue+creddebt+default+yrsed
#starting from income

# %%
#building function
plotVar <- function(var, breaks=20, label='')
{
    hist(var, freq=FALSE, breaks=breaks, col=rgb(1,1,0,0.4), 
         main=paste('Histogram of', label), xlab=label)
    curve(dnorm(x, mean=mean(var), sd=sd(var)), 
          from=min(var), to=max(var),
          col='red', lw=4, add=TRUE)
}

# %%
ks <- function(x)
{ set.seed(13); ks.test(x, rnorm(mean=mean(x), sd=sd(x), n=length(x))) }

# %% [markdown]
# # Income

# %%
plotVar(IncomeData$income, label='income')
# Out:
# Plot with title "Histogram of income"

# %%
plotVar(IncomeData3$income, label='income')
# Out:
# Plot with title "Histogram of income"

# %%
caret::BoxCoxTrans(IncomeData3$income)
# Out:
# Box-Cox Transformation
#
# 3700 data points used to estimate Lambda
#
# Input data summary:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    9.00   21.00   33.00   39.56   51.00  133.00
#
# Largest/Smallest: 14.8
# Sample Skewness: 1.31
#
# Estimated Lambda: 0
# With fudge factor, Lambda = 0 will be used for transformations

# %%
#box cox suggest log transform
plotVar(log(IncomeData3$income), label='log(income)')
# Out:
# Plot with title "Histogram of log(income)"

# %%
ks(log(IncomeData3$income))
# Out:
# Warning message in ks.test(x, rnorm(mean = mean(x), sd = sd(x), n = length(x))):
# "p-value will be approximate in the presence of ties"
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  x and rnorm(mean = mean(x), sd = sd(x), n = length(x))
# D = 0.031081, p-value = 0.05607
# alternative hypothesis: two-sided

# %% [markdown]
# # Othdebt

# %%
#plotVar(IncomeData3$income, label='income')
#caret::BoxCoxTrans(IncomeData3$income)
#plotVar(log(IncomeData3$income), label='log(income)')
#ks(log(IncomeData3$income))

# %%
plotVar(IncomeData3$othdebt, label='Other Debt')
# Out:
# Plot with title "Histogram of Other Debt"

# %%
caret::BoxCoxTrans(IncomeData3$othdebt)
# Out:
# Box-Cox Transformation
#
# 3700 data points used to estimate Lambda
#
# Input data summary:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0.02064 0.83433 1.61878 2.17554 3.04706 8.13899
#
# Largest/Smallest: 394
# Sample Skewness: 1.18
#
# Estimated Lambda: 0.3

# %%
plotVar(IncomeData3$othdebt^(1/3), label='sqrt(Other Debt)')
# Out:
# Plot with title "Histogram of sqrt(Other Debt)"

# %%
ks(sqrt(IncomeData3$othdebt))
# Out:
# Warning message in ks.test(x, rnorm(mean = mean(x), sd = sd(x), n = length(x))):
# "p-value will be approximate in the presence of ties"
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  x and rnorm(mean = mean(x), sd = sd(x), n = length(x))
# D = 0.056216, p-value = 1.67e-05
# alternative hypothesis: two-sided

# %% [markdown]
# # Carvalue

# %%
plotVar(IncomeData3$carvalue, label='Car Value')
# Out:
# Plot with title "Histogram of Car Value"

# %%
caret::BoxCoxTrans(IncomeData3$carvalue)
# Out:
# Box-Cox Transformation
#
# 3700 data points used to estimate Lambda
#
# Input data summary:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    2.20   10.10   16.10   19.77   25.70   95.60
#
# Largest/Smallest: 43.5
# Sample Skewness: 1.5
#
# Estimated Lambda: 0
# With fudge factor, Lambda = 0 will be used for transformations

# %%
plotVar(log(IncomeData3$carvalue), label='log(Car Value)')
# Out:
# Plot with title "Histogram of log(Car Value)"

# %%
ks(sqrt(IncomeData3$carvalue))
# Out:
# Warning message in ks.test(x, rnorm(mean = mean(x), sd = sd(x), n = length(x))):
# "p-value will be approximate in the presence of ties"
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  x and rnorm(mean = mean(x), sd = sd(x), n = length(x))
# D = 0.06973, p-value = 3.076e-08
# alternative hypothesis: two-sided

# %% [markdown]
# # Creddebt

# %%
plotVar(IncomeData3$creddebt, label='creddebt')
# Out:
# Plot with title "Histogram of creddebt"

# %%
caret::BoxCoxTrans(IncomeData3$creddebt)
# Out:
# Box-Cox Transformation
#
# 3700 data points used to estimate Lambda
#
# Input data summary:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# 0.001364 0.326732 0.738036 0.994184 1.405732 3.969160
#
# Largest/Smallest: 2910
# Sample Skewness: 1.24
#
# Estimated Lambda: 0.3

# %%
plotVar(IncomeData3$creddebt^(1/3), label='sqrt(creddebt)')
# Out:
# Plot with title "Histogram of sqrt(creddebt)"

# %%
ks(IncomeData3$creddebt^(1/3))
# Out:
# Warning message in ks.test(x, rnorm(mean = mean(x), sd = sd(x), n = length(x))):
# "p-value will be approximate in the presence of ties"
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  x and rnorm(mean = mean(x), sd = sd(x), n = length(x))
# D = 0.038108, p-value = 0.009278
# alternative hypothesis: two-sided

# %% [markdown]
# # yrsed

# %%
plotVar(IncomeData3$yrsed, label='yrsed')
# Out:
# Plot with title "Histogram of yrsed"

# %%
caret::BoxCoxTrans(IncomeData3$yrsed)
# Out:
# Box-Cox Transformation
#
# 3700 data points used to estimate Lambda
#
# Input data summary:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    6.00   12.00   14.00   14.35   17.00   23.00
#
# Largest/Smallest: 3.83
# Sample Skewness: 0.0514
#
# Estimated Lambda: 0.8
# With fudge factor, no transformation is applied

# %% [markdown]
# # BUILD MODEL STARTING FROM ALL VARIABLES

# %% [markdown]
# # Simple Linear Model

# %%
#CREATING A MODEL WITH ALL THE VARIABLES
model3 <- lm(income ~ othdebt+carvalue+creddebt+default+yrsed, IncomeData3)
summary(model3)
# Out:
# Call:
# lm(formula = income ~ othdebt + carvalue + creddebt + default +
#     yrsed, data = IncomeData3)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -44.900  -4.384  -1.062   3.185  51.565
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.90995    0.64356   2.968  0.00302 **
# othdebt      0.96944    0.09509  10.195  < 2e-16 ***
# carvalue     1.64168    0.01236 132.790  < 2e-16 ***
# creddebt     1.16036    0.18636   6.227 5.30e-10 ***
# default     -2.10630    0.34869  -6.041 1.69e-09 ***
# yrsed        0.16607    0.04335   3.831  0.00013 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 8.417 on 3694 degrees of freedom
# Multiple R-squared:  0.8857,	Adjusted R-squared:  0.8856
# F-statistic:  5727 on 5 and 3694 DF,  p-value: < 2.2e-16

# %%
vif(model3)
# Out:
#  othdebt carvalue creddebt  default    yrsed
# 1.480613 1.424350 1.358546 1.074236 1.036126

# %%
sigma(model3)*100/mean(IncomeData3$income)
# Out:
# [1] 21.2761

# %%
ncvTest(model3)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 1894.874, Df = 1, p = < 2.22e-16

# %% [markdown]
# # SYNTHETIC MODEL

# %%
SyntMod <- lm(log(income) ~ exp(0.3*log(othdebt)) + log(carvalue) + exp(0.3*log(creddebt)) + default + yrsed, data=IncomeData3)
summary(SyntMod)
# Out:
# Call:
# lm(formula = log(income) ~ exp(0.3 * log(othdebt)) + log(carvalue) +
#     exp(0.3 * log(creddebt)) + default + yrsed, data = IncomeData3)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.52087 -0.12885 -0.01505  0.11241  1.07928
#
# Coefficients:
#                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)               0.9188846  0.0192804  47.659  < 2e-16 ***
# exp(0.3 * log(othdebt))   0.1305775  0.0129097  10.115  < 2e-16 ***
# log(carvalue)             0.8276336  0.0058353 141.833  < 2e-16 ***
# exp(0.3 * log(creddebt))  0.0801971  0.0144036   5.568 2.76e-08 ***
# default                  -0.0465697  0.0078842  -5.907 3.80e-09 ***
# yrsed                     0.0043927  0.0009854   4.458 8.54e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.1912 on 3694 degrees of freedom
# Multiple R-squared:  0.9015,	Adjusted R-squared:  0.9014
# ...

# %%
ncvTest(SyntMod)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 57.55745, Df = 1, p = 3.2825e-14

# %%
#computing the percentage of residual standard error


sigma(SyntMod)/mean(IncomeData3$income)
# Out:
# [1] 0.00483362

# %%
ncvTest(SyntMod)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 57.55745, Df = 1, p = 3.2825e-14

# %% [markdown]
# # log linear model

# %%
loglinm <- lm(log(income) ~ othdebt+carvalue+creddebt+default+yrsed, data=IncomeData3)
summary(loglinm)
# Out:
# Call:
# lm(formula = log(income) ~ othdebt + carvalue + creddebt + default +
#     yrsed, data = IncomeData3)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.53125 -0.14813  0.01937  0.17636  0.92862
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.5486228  0.0206915 123.172  < 2e-16 ***
# othdebt      0.0390305  0.0030574  12.766  < 2e-16 ***
# carvalue     0.0359820  0.0003975  90.522  < 2e-16 ***
# creddebt     0.0596431  0.0059918   9.954  < 2e-16 ***
# default     -0.0364562  0.0112111  -3.252  0.00116 **
# yrsed        0.0068712  0.0013938   4.930 8.58e-07 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2706 on 3694 degrees of freedom
# Multiple R-squared:  0.8028,	Adjusted R-squared:  0.8025
# F-statistic:  3007 on 5 and 3694 DF,  p-value: < 2.2e-16

# %%
sigma(loglinm)*100/mean(IncomeData3$income)
# Out:
# [1] 0.6840647

# %%
ncvTest(loglinm)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 105.1661, Df = 1, p = < 2.22e-16

# %%
vif(loglinm)
# Out:
#  othdebt carvalue creddebt  default    yrsed
# 1.480613 1.424350 1.358546 1.074236 1.036126

# %% [markdown]
# # log log model

# %%
loglogm <- lm(log(income) ~ log(othdebt) + log(carvalue) + 
                          log(creddebt) + default + yrsed, 
              data=IncomeData3)
summary(loglogm)
# Out:
# Call:
# lm(formula = log(income) ~ log(othdebt) + log(carvalue) + log(creddebt) +
#     default + yrsed, data = IncomeData3)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.52630 -0.12838 -0.01415  0.11257  1.09384
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    1.1181394  0.0202438  55.234  < 2e-16 ***
# log(othdebt)   0.0400804  0.0042585   9.412  < 2e-16 ***
# log(carvalue)  0.8342163  0.0057443 145.226  < 2e-16 ***
# log(creddebt)  0.0156974  0.0036041   4.355 1.36e-05 ***
# default       -0.0441846  0.0079045  -5.590 2.44e-08 ***
# yrsed          0.0043698  0.0009898   4.415 1.04e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.192 on 3694 degrees of freedom
# Multiple R-squared:  0.9007,	Adjusted R-squared:  0.9005
# F-statistic:  6699 on 5 and 3694 DF,  p-value: < 2.2e-16

# %%
sigma(loglogm)*100/mean(IncomeData3$income)
# Out:
# [1] 0.4854655

# %%
ncvTest(loglogm)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 62.43819, Df = 1, p = 2.7494e-15

# %%
vif(loglogm)
# Out:
#  log(othdebt) log(carvalue) log(creddebt)       default         yrsed
#      1.711268      1.418118      1.558587      1.060297      1.037467

# %% [markdown]
# # CHECK MODELS

# %% [markdown]
# # TEST OF NORMALITY OF RESIDUALS

# %% [markdown]
# # Simple Linear Model

# %%
res <- summary(model3)$residuals
plotVar(res, label='Residuals')
# Out:
# Plot with title "Histogram of Residuals"

# %%
qqnorm(res)
qqline(res, col='red', lwd=4)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
ks(res)
# Out:
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  x and rnorm(mean = mean(x), sd = sd(x), n = length(x))
# D = 0.096216, p-value = 2.665e-15
# alternative hypothesis: two-sided

# %% [markdown]
# # Synthetic Model

# %%
res <- summary(SyntMod)$residuals
plotVar(res, label='Residuals of linm')
# Out:
# Plot with title "Histogram of Residuals of linm"

# %%
qqnorm(res)
qqline(res, col='red', lwd=4)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
ks(res)
# Out:
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  x and rnorm(mean = mean(x), sd = sd(x), n = length(x))
# D = 0.035135, p-value = 0.02077
# alternative hypothesis: two-sided

# %% [markdown]
# # log linear Model

# %%
res <- summary(loglinm)$residuals
plotVar(res, label='Residuals of linm')
# Out:
# Plot with title "Histogram of Residuals of linm"

# %%
qqnorm(res)
qqline(res, col='red', lwd=4)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
ks(res)
# Out:
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  x and rnorm(mean = mean(x), sd = sd(x), n = length(x))
# D = 0.045946, p-value = 0.0008107
# alternative hypothesis: two-sided

# %% [markdown]
# # loglogm

# %%
res <- summary(loglogm)$residuals
plotVar(res, label='Residuals of loglogm')
# Out:
# Plot with title "Histogram of Residuals of loglogm"

# %%
qqnorm(res)
qqline(res, col='red', lwd=4)
# Out:
# Plot with title "Normal Q-Q Plot"

# %%
ks(res)
# Out:
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  x and rnorm(mean = mean(x), sd = sd(x), n = length(x))
# D = 0.037568, p-value = 0.01079
# alternative hypothesis: two-sided

# %% [markdown]
# # Test of Homoscedasticity

# %%
par(mfrow=c(2,2))
plot(model3, col=rgb(0.8,0.7,0,0.4))
# Out:
# Plot with title ""

# %%
par(mfrow=c(2,2))
plot(SyntMod, col=rgb(0.8,0.7,0,0.4))
# Out:
# Plot with title ""

# %%
vif(SyntMod)
# Out:
#  exp(0.3 * log(othdebt))            log(carvalue) exp(0.3 * log(creddebt))
#                 1.672427                 1.476171                 1.523465
#                  default                    yrsed
#                 1.064054                 1.037416

# %%
ncvTest(SyntMod)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 57.55745, Df = 1, p = 3.2825e-14

# %%
par(mfrow=c(2,2))
plot(loglinm
     , col=rgb(0.8,0.7,0,0.4))
# Out:
# Plot with title ""

# %%
ncvTest(loglinm)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 105.1661, Df = 1, p = < 2.22e-16

# %%
par(mfrow=c(2,2))
plot(loglogm, col=rgb(0.8,0.7,0,0.4))
# Out:
# Plot with title ""

# %%
ncvTest(loglogm)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 62.43819, Df = 1, p = 2.7494e-15
